# %%
        import numpy as np
        import pandas as pd
        import seaborn as sns
        import matplotlib.pyplot as plt
        from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
        from sklearn.naive_bayes import MultinomialNB
        from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, r2_score
        from sklearn.preprocessing import LabelEncoder
        from sklearn.linear_model import LogisticRegression

# %%
try:
    df_test = pd.read_csv('train_data.txt', sep=":::", header=0, engine="python")
    print("File loaded successfully!")
except FileNotFoundError:
    print("File not found")
# Out:
# File loaded successfully!

# %%
try:
    df_test = pd.read_csv('test_data_solution.txt', sep=":::", header=0, engine="python")
    print("File loaded successfully!")
except FileNotFoundError:
    print("File not found. Please double-check the path:")
# Out:
# File loaded successfully!

# %%
try:
    df_test = pd.read_csv('test_data_solution.txt', sep=":::", header=0, engine="python")
    print("File loaded successfully!")
except FileNotFoundError:
    print("File not found. Please double-check the path:")
# Out:
# File loaded successfully!

# %%
try:
    df_test = pd.read_csv('test_data_solution.txt', sep=":::", header=0, engine="python")
    print("File loaded successfully!")
except FileNotFoundError:
    print("File not found. Please double-check the path:")
# Out:
# File loaded successfully!

# %%
 print(df_test.columns)
# Out:
# Index(['1 ', ' Edgar's Lunch (1998) ', ' thriller ',
#        ' L.R. Brane loves his life - his car, his apartment, his job, but especially his girlfriend, Vespa. One day while showering, Vespa runs out of shampoo. L.R. runs across the street to a convenience store to buy some more, a quick trip of no more than a few minutes. When he returns, Vespa is gone and every trace of her existence has been wiped out. L.R.'s life becomes a tortured existence as one strange event after another occurs to confirm in his mind that a conspiracy is working against his finding Vespa.'],
#       dtype='object')

# %%
df_test.head()
# Out:
#    1           Edgar's Lunch (1998)       thriller   \
# 0   2      La guerra de papá (1977)         comedy
# 1   3   Off the Beaten Track (2010)    documentary
# 2   4        Meu Amigo Hindu (2015)          drama
# 3   5             Er nu zhai (1955)          drama
# 4   6            Riddle Room (2016)         horror
#
#    L.R. Brane loves his life - his car, his apartment, his job, but especially his girlfriend, Vespa. One day while showering, Vespa runs out of shampoo. L.R. runs across the street to a convenience store to buy some more, a quick trip of no more than a few minutes. When he returns, Vespa is gone and every trace of her existence has been wiped out. L.R.'s life becomes a tortured existence as one strange event after another occurs to confirm in his mind that a conspiracy is working against his finding Vespa.
# 0   Spain, March 1964: Quico is a very naughty ch...
# 1   One year in the life of Albin and his family ...
# ...

# %%
try:
    df_train_data = pd.read_csv('train_data.csv', sep=":::", header=0, engine="python")
    print("Train data file loaded successfully!")
    df_train_data.head()
except FileNotFoundError:
    print("File not found. Please double-check the path:")
# Out:
# File not found. Please double-check the path:

# %%
        df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9622 entries, 0 to 9621
# Data columns (total 4 columns):
#  #   Column                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Non-Null Count  Dtype
# ...

# %%
try:
    df_train_data = pd.read_csv('train_data.csv', sep=":::", header=0, engine="python")
    print("Train data file loaded successfully!")
    df_train_data.head()
except FileNotFoundError:
    print("File not found. Please double-check the path:")
    df_train_data = None

if df_train_data is not None:
    df_train_data.describe()
# Out:
# File not found. Please double-check the path:

# %%
df_test.isnull().sum()
# Out:
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 0
# ...

# %%
df_test.describe()
# Out:
#                 1
# count  9622.000000
# mean   4812.500000
# std    2777.776479
# min       2.000000
# 25%    2407.250000
# 50%    4812.500000
# 75%    7217.750000
# max    9623.000000

# %%
# !echo 'col1:::col2:::col3' > train_data.csv
# !echo '1:::2:::3' >> train_data.csv
# !echo '4:::5:::6' >> train_data.csv
# !echo '7:::8:::9' >> train_data.csv

import pandas as pd
try:

    df_train_data = pd.read_csv('train_data.csv', sep=":::", header=0, engine="python")
    print("Train data file loaded successfully!")
    df_train_data.head()
except FileNotFoundError:

    print("File not found. Please double-check the path:")
    df_train_data = None

if df_train_data is not None:

    df_train_data.describe()

df_train_data.isnull().sum()
# Out:
# Train data file loaded successfully!
# col1    0
# col2    0
# col3    0
# dtype: int64

# %%
try:
    df_train_data = pd.read_csv('train_data.csv', sep=":::", header=0, engine="python")
    print("Train data file loaded successfully!")
    df_train_data.head()
except FileNotFoundError:
    print("File not found")
    df_train_data = None

if df_train_data is not None:
    df_train_data.isnull().sum()
# Out:
# File not found

# %%
try:
    df_train_data = pd.read_csv('train_data.csv', sep=":::", header=0, engine="python")
    print("Train data file loaded successfully!")
    df_train_data.head()
except FileNotFoundError:
    print("File not found")
    df_train_data = None

if df_train_data is not None:
    df_train_data.count()
# Out:
# File not found

# %%
df_test.count()
# Out:
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 9622
# ...

# %%
df_test.duplicated().sum()
# Out:
# 0

# %%
try:
    df_train_data = pd.read_csv('train_data.csv', sep=":::", header=0, engine="python")
    print("Train data file loaded successfully!")
    df_train_data.head()
except FileNotFoundError:
    print("File not found. Please double-check the path:")
    df_train_data = None

if df_train_data is not None:
    df_train_data.isnull().sum()
    print(df_train_data.duplicated().sum())
else:
    print("Cannot perform operations on df_train_data as it is None.")
# Out:
# File not found. Please double-check the path:
# Cannot perform operations on df_train_data as it is None.

# %%
df_train_data = pd.DataFrame({'col1': [1, 2], 'col2': [3, 4]})
df_train_data.iloc[0:3]
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
df_test.iloc[0:3]
# Out:
#    1           Edgar's Lunch (1998)       thriller   \
# 0   2      La guerra de papá (1977)         comedy
# 1   3   Off the Beaten Track (2010)    documentary
# 2   4        Meu Amigo Hindu (2015)          drama
#
#    L.R. Brane loves his life - his car, his apartment, his job, but especially his girlfriend, Vespa. One day while showering, Vespa runs out of shampoo. L.R. runs across the street to a convenience store to buy some more, a quick trip of no more than a few minutes. When he returns, Vespa is gone and every trace of her existence has been wiped out. L.R.'s life becomes a tortured existence as one strange event after another occurs to confirm in his mind that a conspiracy is working against his finding Vespa.
# 0   Spain, March 1964: Quico is a very naughty ch...
# 1   One year in the life of Albin and his family ...
# 2   His father has died, he hasn't spoken with hi...

# %%
print(df_test.head())
first_row=df_test.iloc[0]
print("first_row")
# Out:
#    1           Edgar's Lunch (1998)       thriller   \
# 0   2      La guerra de papá (1977)         comedy
# 1   3   Off the Beaten Track (2010)    documentary
# 2   4        Meu Amigo Hindu (2015)          drama
# 3   5             Er nu zhai (1955)          drama
# 4   6            Riddle Room (2016)         horror
#
#    L.R. Brane loves his life - his car, his apartment, his job, but especially his girlfriend, Vespa. One day while showering, Vespa runs out of shampoo. L.R. runs across the street to a convenience store to buy some more, a quick trip of no more than a few minutes. When he returns, Vespa is gone and every trace of her existence has been wiped out. L.R.'s life becomes a tortured existence as one strange event after another occurs to confirm in his mind that a conspiracy is working against his finding Vespa.
# 0   Spain, March 1964: Quico is a very naughty ch...
# 1   One year in the life of Albin and his family ...
# ...

# %%
df_test.shape
# Out:
# (9622, 4)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

file_path = r'D:\\archive (2)\\Genre Classification Dataset\\train_data.txt'
import os
if os.path.exists(file_path):
    df_train = pd.read_csv(file_path)
    plt.figure(figsize=(14, 10))
    sns.countplot(x='category', data=df_train)
    plt.xlabel('movie category')
    plt.ylabel('count')
    plt.title('Movie genre plot')
    plt.xticks(rotation=90)
    plt.show()
else:
    print(f"File not found at: {file_path}")
# Out:
# File not found at: D:\\archive (2)\\Genre Classification Dataset\\train_data.txt

# %%
vectorizer = TfidfVectorizer()
